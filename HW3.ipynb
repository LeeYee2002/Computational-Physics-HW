# %% [markdown]
# # Computational Physics (Physics 760) Exercise #3

# %% [markdown]
# **LI, YI-QUAN(Eric)** and **Jenish**
#
# **uni-ID:s08yli** and **s6jeadhi**
#
# **github-address: https://github.com/LeeYee2002/Computational-Physics-HW.git**

# %% [markdown]
# **(1pt) The variance is the second central moment, $σ^2 = \langle (x−µ)^2 \rangle$ . Prove it is equal to $x^2 −{⟨x⟩}^2$**
#
# $$\langle (x−µ)^2 \rangle = \langle \sum_{i}^n (x_i-\mu)^2 \rangle$$
#
# Where $\mu$ is the average of samples: $$\mu = \frac{\sum^n_{i} x_i}{n}$$
#
# Expand the square:
#
# $$\langle \sum_{i}^n (x_i-\mu)^2 \rangle = \langle \sum_{i}^n x_i^2 -2\mu x_i + \mu^2 \rangle$$
#
# From the above relation:
#
# $$\langle \sum_{i}^n x_i^2 -2\mu x_i + \mu^2 \rangle = \langle \sum_{i}^nx_i^2 -2\mu \sum_{i}^n x_i + \sum_{i}^n \mu^2 \rangle = \langle \sum_{i}^nx_i^2 -2\mu (n \mu) + n \mu^2 \rangle = \langle x \rangle$$

# %% [markdown]
# Rearrange the equation:
# $$\langle \sum_{i}^nx_i^2 -2\mu (n \mu) + n \mu^2 \rangle = \langle \sum_{i}^nx_i^2 -n\mu^2  \rangle$$

# %% [markdown]
# Use the sumation notation for $\mu$:
# $$\langle \sum_{i}^nx_i^2 -\sum_{i}^n \mu^2  \rangle$$
# We know the expectation value have simple additivity:

# %% [markdown]
# $$\langle \sum_{i}^nx_i^2 -\sum_{i}^n \mu^2  \rangle = \langle \sum_{i}^nx_i^2\rangle -\langle \sum_{i}^n \mu^2  \rangle = \langle \sum_{i}^nx_i^2\rangle - \mu^2 =\langle x^2\rangle - \langle x \rangle ^2$$

# %% [markdown]
# Such that:
#
# $$σ^2 = \langle (x−µ)^2 \rangle =\langle x^2\rangle - \langle x \rangle ^2$$

# %% [markdown]
# **(3pt) To third order G(k) = $\exp(ikµ − \frac{k^2}{2} σ^2 − \frac{ik^3}{6} κ_3 +O(k^4) )$. Prove that this third cumulant κ_3 is the third central moment $(x−µ)^3$**:

# %% [markdown]
# Expand $G(k)$ to third order:
#
# $$G(k) = 1 +ik\mu -\frac{1}{2} k^2 \langle x^2 \rangle -\frac{ik^3}{6} \langle x^3 \rangle + O(k^4)...$$

# %% [markdown]
# We first analyze $\kappa_3$:
# $$\kappa_3 = \langle (x-\mu)^3 \rangle = \langle x^3-3x^2\mu +3x \mu^2 -\mu^3 \rangle = \langle x^3 \rangle -3\mu(\langle x^2 \rangle - \mu \langle x \rangle) -\mu^3$$
# Then we focus on the latter part:
# $$ \langle x^3 \rangle -3\mu(\langle x^2 \rangle - \mu \langle x \rangle) -\mu^3 = \langle x^3 \rangle -3\mu(\langle x^2 \rangle - \mu^2) -\mu^3 $$

# %% [markdown]
# Where we see the variance; thus, we can write $\kappa_3$ as:

# %% [markdown]
# $$\kappa_3 = \langle x^3 \rangle -3\mu \sigma^2 -\mu^3$$

# %% [markdown]
# One can rearrange the formula:

# %% [markdown]
# $$\langle x^3 \rangle = \kappa_3 +3\mu \sigma^2 +\mu^3$$

# %% [markdown]
# Return to the expansion of $G(k)$, we insert the relation above, where $G(k)$ becomes:

# %% [markdown]
# $$G(k) = 1 +ik\mu -\frac{1}{2}k^2\langle x^2 \rangle -\frac{ik^3}{6} (\kappa_3 +3\mu \sigma^2 +\mu^3) + O(k^4)...$$

# %% [markdown]
# By the first question we have $\langle x^2 \rangle =(\sigma^2 + \mu^2)$:

# %% [markdown]
# $$G(k) = 1 +ik\mu -\frac{1}{2}k^2(\sigma^2 + \mu^2) -\frac{ik^3}{6} (\kappa_3 +3\mu \sigma^2 +\mu^3) + O(k^4)...$$

# %% [markdown]
# Now everything is ready. Then we suppose G(k) can be formulated by three product of expoential:

# %% [markdown]
# $$G(k) = \exp(ik\mu -\frac{1}{2} k^2\sigma^2 -\frac{ik^3}{6}\kappa_3 +O(k^4)) = \exp(ik \mu) \cdot \exp(-\frac{1}{2} k^2\sigma^2) \cdot \exp(-\frac{ik^3}{6}\kappa_3) \cdot \exp(O(k^4))$$

# %% [markdown]
# By Taylor expansion:
#
# $$G(k) = (1 -ik\mu -\frac{1}{2} k^2 \mu^2 - \frac{ik^3}{6}\mu^3...)(1 - \frac{1}{2}k^2 \sigma^2...)(1 - \frac{-ik^3}{6} \kappa_3...)$$

# %% [markdown]
# Expand this representation of $G(k)$, we will once again attain:
# $$G(k) = 1 +ik\mu -\frac{1}{2}k^2(\sigma^2 + \mu^2) -\frac{ik^3}{6} (\kappa_3 +3\mu \sigma^2 +\mu^3) + O(k^4)...$$

# %% [markdown]
# As a result, we hereby prove the relation:
# $$\kappa_3 = \langle(x-\mu)^3 \rangle $$
#
# Q.E.D

# %% [markdown]
# **The Laplace distribution is the two-sided exponential distribution**
#
#
# $$L_{µ,b}(x) = \frac{1}{2b}\exp(\frac{−|x−µ|}{b})$$
#
# **We can see obviously the distribution is symmetric around µ(so µ is the median of $L_{µ,b}$), and the probability peaks there (so µ is the mode of $L_{µ,b}$).**
#
# **Perform X = 1000 experiments where you draw T = $2^{11}$ iid samples from $L_{0,1}$. Let’s imagine the samples in any experiment are drawn sequentially and we can say we accumulate more and more samples as a function of time $t$.**

# %% [markdown]
# **• (1pt) For a single experiment make a histogram of all the samples x and compare it to $L_{0,1}$**
#
# Such $L_{0,1}$:
#
# $$L_{0,1}(x) = \frac{1}{2} \exp(- |x| )$$

# %%
def laplace(mu,b,x):
    import math
    e =math.e
    return 1/(2*b)*e**(-abs(x-mu)/b)

# %%
import numpy as np
import matplotlib.pyplot as plt
mu, b = 0, 1
experiments = 1
samples = 2**11
result = np.random.laplace(mu,b, samples)

x_0 = np.linspace(-10,10,1000) #as we see laplace distribution in this case most falls with -10~10
y_0 = laplace(mu,b,x_0)
plt.hist(result, bins = 100, label = '$L_{0,1}$ histogram', density= True)
plt.plot(x_0,y_0, color ='r', label ='$L_{0,1}$ function')
plt.title("Single Laplace Experiment")
plt.legend()
plt.show()

# %% [markdown]
# **(2pts) For 20 of the experiments plot $S_t$ as a function of time t. t runs from 1 (the beginning of the experiment where the sample average for any experiment is the one lonely sample in the experiment ‘so far’) all the way to T (the end of the experiment). You can plot them all on the same plot, or present them however you think is clear.**

# %% [markdown]
# $S_t$ by the definition:
#
# $$S_n = \frac{1}{n} \sum^n_{j=1} x_j$$

# %%
import numpy as np
import matplotlib.pyplot as plt
mu, b = 0, 1
experiments = 20
samples = 2**11
t_0 = np.linspace(1,2**11)  #t : time dependent
for i in range(experiments):
    experiment_record = [] #we record all result from an experiment, from t=1 ~2**11
    experiment_average_record = [] #we record our average S_t
    for t in t_0:
        result = np.random.laplace(mu,b,1)
        #print(result)
        experiment_record.append(result)
        experiment_average_record.append(sum(experiment_record)/len(experiment_record))
    plt.plot(t_0,experiment_average_record, alpha = 0.5)

plt.title("20 plots for $S_t$")
plt.xlabel("t")
plt.show()

# %% [markdown]
# **(2pts) Make a figure with normalized histograms of St for t ∈ {8,32,128,512}. (Each histogram contains X = 1000 running averages.)**

# %%
import numpy as np
import matplotlib.pyplot as plt
mu, b = 0, 1
experiments = 1000
#samples = 2**11
t_0 = np.linspace(1,2**11)  #t : time dependent
analysis_condition = [8 ,32, 128, 512] # the set of different t
colors = ['b','g','r','c']
S_t_labels = ["t=8","t=32",'t=128','t=512']
histogram_data = np.empty(shape=(1000,4))
for i in range(4): # t=8, t=32, t=128, t=512
    experiment_average_record = [] #we record our average S_t
    for x in range(experiments):#we do 1000 times for different t
        experiment_record = [] #we record all result from an experiment, from 1~t 
        for running_time in range(analysis_condition[i]):#do t times exp
            result = np.random.laplace(mu,b)
            experiment_record.append(result) #record t datas
        experiment_average_record.append(sum(experiment_record)/len(experiment_record)) #attain S_t
    histogram_data[:,i] = np.array(experiment_average_record) #we put our result to the bigest one store place
#print(np.array(histogram_data).shape)
plt.hist(histogram_data, bins= 10, color= colors,density= True, label=S_t_labels)
plt.title("plots of $S_t$ for different t")
plt.legend()
plt.show()

# %% [markdown]
# **(3pts) Plot the estimated uncertainty of St as a function of t on a log-log plot. Describe what you see and explain how it is related to the CLT.**

# %%
import numpy as np
import matplotlib.pyplot as plt
mu, b = 0, 1
experiments = 1000
t= [1, 2, 4, 8, 16 ,32,64, 128, 256, 512, 1024, 2048] # the set of different t
s_t_uncertainty = []
for i in range(12): # 
    experiment_average_record = [] #we record our average S_t
    for x in range(experiments):#we do 1000 times for different t
        experiment_record = [] #we record all result from an experiment, from 1~t 
        for running_time in range(t[i]):#do t times exp
            result = np.random.laplace(mu,b)
            experiment_record.append(result) #record t datas
        experiment_average_record.append(sum(experiment_record)/len(experiment_record)) #attain S_t
    s_t_uncertainty.append(np.array(experiment_average_record).std() ) #we put our result to the uncertainty recorder
#print(np.array(histogram_data).shape)
plt.plot(np.log2(t), np.log2(s_t_uncertainty),marker = 'o')
plt.title("plot of uncertainty of $S_t$ for different t, log2-log2")
plt.xlabel("log2(t)")
plt.ylabel("log2($\sigma_t$)")
plt.legend()
plt.show()
# Out:
# <>:20: SyntaxWarning: invalid escape sequence '\s'
# <>:20: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\88697\AppData\Local\Temp\ipykernel_29620\3947304695.py:20: SyntaxWarning: invalid escape sequence '\s'
#   plt.ylabel("log2($\sigma_t$)")
# C:\Users\88697\AppData\Local\Temp\ipykernel_29620\3947304695.py:21: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %% [markdown]
# We see from these questions, as we taking more samples in different experiments to calculate the average($\mu$), we will find out that our observalble, our result will converage. As we see that "more tests and less uncertainty". Which can explain the expects of CLT, the uncertainty converage to 0 as $n \rightarrow \infty$:

# %% [markdown]
# $$\sigma^2_n = \frac{\langle \sigma^2 \rangle}{n}$$

# %% [markdown]
# It shows that our calculated result of $\langle x \rangle$ will tend to the real average $\mu$, as we have less uncertainty. CLT shows a natural tendency for all large number experiments data. The statistical result of numerous *iid* observable(average, or whatever we want), turns out to be a normal distribution. That is, we all know, if we can have a perfect Gaussian with 0 uncertatity, which is Dirac-delta function.
#
# Dirac delta function is an extreme case of normal distribution, in that case uncertainty is not existed. We can imagine, if we can make infinity experiemts, CLT predict we will converge to one precise answer with schinking uncertainty. That is, closing to normal distribution and then-- delta-function.

# %% [markdown]
# ### 3.3 [8 points] A Long-Tailed Distribution

# %% [markdown]
# We will essentially repeat the previous problem. However, you should see something very different. Perform the same X = 1000 experiments of drawing T = $2^{11}$ iid samples, but from $C_{0,1}$.

# %% [markdown]
# $$C_{x_0,\gamma} = \frac{1}{\gamma \pi} \frac{1}{ 1 + (\frac{x-x_0}{\gamma})^2}$$

# %% [markdown]
# **(2pts) For 20 of the experiments plot $S_t$ as a function of time t. t runs from 1 (the beginning of the experiment where the sample average for any experiment is the one lonely sample in the experiment ‘so far’) all the way to T (the end of the experiment).**

# %% [markdown]
# $S_t$ by the definition:
#
# $$S_t = \frac{1}{t} \sum^t_{j=1} x_j$$

# %%
import numpy as np
import matplotlib.pyplot as plt
x_0, gamma = 0, 1
experiments = 20
samples = 2**11
t_0 = np.linspace(1,2**11)  #t : time dependent
for i in range(experiments):
    experiment_record = [] #we record all result from an experiment, from t=1 ~2**11
    experiment_average_record = [] #we record our average S_t
    for t in t_0:
        result =np.random.standard_cauchy(size=None) #which use x_0 =0, gamma = 1. standard cauchy distribution
        #print(result)
        experiment_record.append(result)
        experiment_average_record.append(sum(experiment_record)/len(experiment_record))
    plt.plot(t_0,experiment_average_record, alpha = 0.5)

plt.title("20 plots for $S_t$")
plt.xlabel("t")
plt.show()

# %% [markdown]
# **(2pts) Make a figure with normalized histograms of St for t ∈ {8,32,128,512}. (Each histogram contains X = 1000 running averages.) It might be beneficial to not show the entire histogram but to show some narrow window instead.**

# %%
import numpy as np
import matplotlib.pyplot as plt
mu, b = 0, 1
experiments = 1000
#samples = 2**11
t_0 = np.linspace(1,2**11)  #t : time dependent
analysis_condition = [8 ,32, 128, 512] # the set of different t
colors = ['b','g','r','c']
S_t_labels = ["t=8","t=32",'t=128','t=512']
histogram_data = np.empty(shape=(1000,4))
for i in range(4): # t=8, t=32, t=128, t=512
    experiment_average_record = [] #we record our average S_t
    for x in range(experiments):#we do 1000 times for different t
        experiment_record = [] #we record all result from an experiment, from 1~t 
        for running_time in range(analysis_condition[i]):#do t times exp
            result = np.random.standard_cauchy(size=None)
            experiment_record.append(result) #record t datas
        experiment_average_record.append(sum(experiment_record)/len(experiment_record)) #attain S_t
    histogram_data[:,i] = np.array(experiment_average_record) #we put our result to the bigest one store place
#print(np.array(histogram_data).shape)
plt.hist(histogram_data, bins= 15, range =(-35,35) , color= colors,density= True, label=S_t_labels)
plt.title("plots of $S_t$ for different t")
plt.legend()
plt.show()

# %% [markdown]
# **(3pts) Plot the estimated uncertainty of St as a function of t on a log-log plot. Describe what you see**

# %%
import numpy as np
import matplotlib.pyplot as plt
experiments = 1000
t= [1, 2, 4, 8, 16 ,32,64, 128, 256, 512, 1024, 2048] # the set of different t
s_t_uncertainty = []
for i in range(12): # 
    experiment_average_record = [] #we record our average S_t
    for x in range(experiments):#we do 1000 times for different t
        experiment_record = [] #we record all result from an experiment, from 1~t 
        for running_time in range(t[i]):#do t times exp
            result = np.random.standard_cauchy(size = None)
            experiment_record.append(result) #record t datas
        experiment_average_record.append(sum(experiment_record)/len(experiment_record)) #attain S_t
    s_t_uncertainty.append(np.array(experiment_average_record).std() ) #we put our result to the uncertainty recorder
#print(np.array(histogram_data).shape)
plt.plot(np.log2(t), np.log2(s_t_uncertainty),marker = 'o')
plt.title("plot of uncertainty of $S_t$ for different t, log2-log2")
plt.xlabel("log2(t)")
plt.ylabel("log2($\sigma_t$)")
plt.legend()
plt.show()
# Out:
# <>:19: SyntaxWarning: invalid escape sequence '\s'
# <>:19: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\88697\AppData\Local\Temp\ipykernel_30808\1921739534.py:19: SyntaxWarning: invalid escape sequence '\s'
#   plt.ylabel("log2($\sigma_t$)")
# C:\Users\88697\AppData\Local\Temp\ipykernel_30808\1921739534.py:20: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %% [markdown]
# This time, for the uncertainty corresponding to the measure time t. We didn't find a clear, or absolute trend to show the relation between these two depends. In the last case--Laplace distribution, we can assert that the uncertatinty has negative-correlation to the measurement time(t). In other words, the more experiments we make, the more confident we are to our result. However, this time like chaos, we cann't even indicate there is a kind of "pattern" for our data. Two depends seem to be unrelated.

# %% [markdown]
# **(1pt) Why is this case so different from the Laplace case we previously examined? Provide some explanation as to why the central limit theorem fails.**

# %% [markdown]
# We might rewrite Cauchy-distribution:

# %% [markdown]
# $$C_{x_0=0,\gamma = 1}(x) = \frac{1}{\pi(1+x)^2}$$

# %% [markdown]
# To find the expectation value of the distribution:

# %% [markdown]
# $$E[C(_{0,1}(x))] = \int^ {\infty}_{-\infty} xC_{0,1}(x) dx$$

# %% [markdown]
# Which is:
#
# $$E[C(_{0,1}(x))] = \int^ {\infty}_{-\infty} xC_{0,1}(x) dx = \frac{1}{\pi} \int^ {\infty}_{-\infty} \frac{x}{(1+x)^2} dx$$

# %% [markdown]
# Rewrite equation:
# $$\frac{1}{\pi} \int^ {\infty}_{-\infty} \frac{x}{(1+x)^2} dx = \frac{1}{\pi} \int^ {\infty}_{-\infty} \frac{(1+x)}{(1+x)^2}dx -\frac{1}{\pi} \int^ {\infty}_{-\infty} \frac{1}{(1+x)^2} dx$$

# %% [markdown]
# The first term of integral:
# $$\frac{1}{\pi} \int^ {\infty}_{-\infty} \frac{1+x}{(1+x)^2} dx= \frac{1}{\pi} \int^ {\infty}_{-\infty} \frac{1}{1+x} dx$$

# %% [markdown]
# Which is diverge. It means that **neither the mean value nor the uncertainty of Cauchy-distribution can be defined**. The foundation of Central Limit Theorem requires definite mean value and uncertainty. So this case is not compatiable for us to applying CLT.
